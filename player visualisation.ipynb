# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('sports_dataset.csv')
dataset
# Out:
#       SL  Height  Weight      Sports
# 0      1   171.5    67.7     Cricket
# 1      2   171.9    71.0     Cricket
# 2      3   169.3    67.5     Cricket
# 3      4   174.7    69.5     Cricket
# 4      5   168.6    69.1     Cricket
# ..   ...     ...     ...         ...
# 145  146   184.2    74.0  Basketball
# 146  147   182.6    76.7  Basketball
# 147  148   186.4    73.6  Basketball
# 148  149   171.2    67.5     Cricket
# 149  150   187.0    76.1  Basketball
#
# [150 rows x 4 columns]

# %%
student_data_dis_auto = {}

for class_name in dataset['Sports'].unique():
    student_data_dis_auto[class_name] = dataset[dataset['Sports'] == class_name][['Height', 'Weight']].values.tolist()
student_data_dis_auto
# Out:
# {'Cricket': [[171.5, 67.7],
#   [171.9, 71.0],
#   [169.3, 67.5],
#   [174.7, 69.5],
#   [168.6, 69.1],
#   [168.6, 67.1],
#   [170.7, 64.2],
#   [164.8, 66.9],
#   [167.0, 68.6],
#   [167.3, 65.2],
#   [174.4, 67.5],
#   [170.2, 65.2],
#   [168.4, 68.2],
#   [166.5, 68.8],
#   [168.2, 67.4],
#   [168.2, 71.7],
#   [170.0, 65.9],
#   [172.5, 65.6],
#   [170.6, 64.1],
#   [166.0, 68.4],
#   [172.2, 68.3],
#   [169.7, 67.4],
#   [165.6, 66.6],
#   [168.6, 70.1],
#   [171.0, 64.5],
#   [171.0, 67.2],
#   [168.0, 69.2],
#   [173.1, 69.9],
#   [167.5, 67.4],
#   [171.0, 70.0],
#   [168.6, 67.6],
#   [166.7, 65.6],
#   [172.4, 70.7],
#   [169.8, 70.0],
#   [171.1, 66.7],
#   [171.1, 71.1],
#   [169.9, 71.1],
#   [171.2, 67.5]],
#  'Football': [[152.1, 66.6],
#   [160.3, 64.4],
#   [160.3, 61.0],
#   [159.3, 65.7],
#   [164.4, 64.0],
#   [157.6, 64.0],
#   [162.7, 65.7],
#   [158.4, 66.0],
#   [160.3, 66.9],
#   [157.9, 64.3],
#   [158.8, 62.1],
#   [160.9, 65.5],
#   [160.0, 64.5],
# ...

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(data=dataset, x='Height', y='Weight', hue='Sports', palette='Set2')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>
